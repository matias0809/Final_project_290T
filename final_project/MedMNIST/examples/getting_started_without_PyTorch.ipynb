# %%
# !pip install medmnist
# Out:
# ^C

# %%
from tqdm import tqdm
import numpy as np

import medmnist
from medmnist import INFO, Evaluator
# Out:
# Requirement already satisfied: medmnist in c:\users\matia\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy in c:\users\matia\anaconda3\lib\site-packages (from medmnist) (1.24.3)
# Requirement already satisfied: pandas in c:\users\matia\anaconda3\lib\site-packages (from medmnist) (2.0.3)
# Requirement already satisfied: scikit-learn in c:\users\matia\anaconda3\lib\site-packages (from medmnist) (1.3.0)
# Requirement already satisfied: scikit-image in c:\users\matia\anaconda3\lib\site-packages (from medmnist) (0.20.0)
# Requirement already satisfied: tqdm in c:\users\matia\anaconda3\lib\site-packages (from medmnist) (4.65.0)
# Requirement already satisfied: Pillow in c:\users\matia\anaconda3\lib\site-packages (from medmnist) (9.4.0)
# Requirement already satisfied: fire in c:\users\matia\anaconda3\lib\site-packages (from medmnist) (0.6.0)
# Requirement already satisfied: torch in c:\users\matia\anaconda3\lib\site-packages (from medmnist) (2.2.2)
# Requirement already satisfied: torchvision in c:\users\matia\anaconda3\lib\site-packages (from medmnist) (0.17.2)
# Requirement already satisfied: six in c:\users\matia\anaconda3\lib\site-packages (from fire->medmnist) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\matia\anaconda3\lib\site-packages (from fire->medmnist) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\matia\anaconda3\lib\site-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matia\anaconda3\lib\site-packages (from pandas->medmnist) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\matia\anaconda3\lib\site-packages (from pandas->medmnist) (2023.3)
# Requirement already satisfied: scipy>=1.8 in c:\users\matia\anaconda3\lib\site-packages (from scikit-image->medmnist) (1.11.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\matia\anaconda3\lib\site-packages (from scikit-image->medmnist) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\matia\anaconda3\lib\site-packages (from scikit-image->medmnist) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\matia\anaconda3\lib\site-packages (from scikit-image->medmnist) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\matia\anaconda3\lib\site-packages (from scikit-image->medmnist) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\matia\anaconda3\lib\site-packages (from scikit-image->medmnist) (23.1)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\matia\anaconda3\lib\site-packages (from scikit-image->medmnist) (0.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\matia\anaconda3\lib\site-packages (from scikit-learn->medmnist) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\matia\anaconda3\lib\site-packages (from scikit-learn->medmnist) (2.2.0)
# Requirement already satisfied: filelock in c:\users\matia\anaconda3\lib\site-packages (from torch->medmnist) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\matia\anaconda3\lib\site-packages (from torch->medmnist) (4.10.0)
# Requirement already satisfied: sympy in c:\users\matia\anaconda3\lib\site-packages (from torch->medmnist) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\matia\anaconda3\lib\site-packages (from torch->medmnist) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\matia\anaconda3\lib\site-packages (from torch->medmnist) (2023.4.0)
# Requirement already satisfied: colorama in c:\users\matia\anaconda3\lib\site-packages (from tqdm->medmnist) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matia\anaconda3\lib\site-packages (from jinja2->torch->medmnist) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\matia\anaconda3\lib\site-packages (from sympy->torch->medmnist) (1.3.0)

# %%
print(f"MedMNIST v{medmnist.__version__} @ {medmnist.HOMEPAGE}")
# Out:
# MedMNIST v3.0.1 @ https://github.com/MedMNIST/MedMNIST/

# %%
import dataset_without_pytorch

from dataset_without_pytorch import get_loader

# %% [markdown]
# # We first work on a 2D dataset with size 28x28

# %%
data_flag = 'dermamnist'
# data_flag = 'breastmnist'
download = True

NUM_EPOCHS = 3
BATCH_SIZE = 128
lr = 0.001

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

DataClass = getattr(dataset_without_pytorch, info['python_class'])

# %% [markdown]
# ## First, we read the MedMNIST data, preprocess them and encapsulate them into dataloader form.

# %%
# load the data
train_dataset = DataClass(split='train', download=download)

# encapsulate data into dataloader form
train_loader = get_loader(dataset=train_dataset, batch_size=BATCH_SIZE)
# Out:
# Using downloaded and verified file: C:\Users\matia\.medmnist\dermamnist.npz

# %%
print(train_dataset)
# Out:
# Dataset DermaMNIST (dermamnist)
#     Number of datapoints: 7007
#     Root location: C:\Users\matia\.medmnist
#     Split: train
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'actinic keratoses and intraepithelial carcinoma', '1': 'basal cell carcinoma', '2': 'benign keratosis-like lesions', '3': 'dermatofibroma', '4': 'melanoma', '5': 'melanocytic nevi', '6': 'vascular lesions'}
#     Number of samples: {'train': 7007, 'val': 1003, 'test': 2005}
#     Description: The DermaMNIST is based on the HAM10000, a large collection of multi-source dermatoscopic images of common pigmented skin lesions. The dataset consists of 10,015 dermatoscopic images categorized as 7 different diseases, formulized as a multi-class classification task. We split the images into training, validation and test set with a ratio of 7:1:2. The source images of 3×600×450 are resized into 3×28×28.
#     License: CC BY-NC 4.0

# %%
# visualization

train_dataset.montage(length=1)
# Out:
# <PIL.Image.Image image mode=RGB size=28x28>

# %%
# montage

train_dataset.montage(length=20)
# Out:
# <PIL.Image.Image image mode=RGB size=560x560>

# %%
x, y = train_dataset[0]
print(np.array(x).shape, y.shape)
# Out:
# (28, 28, 3) (1,)

# %%
for x, y in train_loader:
    print(x.shape, y.shape)
    break
# Out:
# (128, 28, 28, 3) (128, 1)

# %% [markdown]
# # We then check a 2D dataset with size 128x128

# %%
data_flag = 'dermamnist'
download = True


info = INFO[data_flag]
DataClass = getattr(dataset_without_pytorch, info['python_class'])

# load the data
train_dataset = DataClass(split='train', download=download, size=128, mmap_mode='r')

# encapsulate data into dataloader form
train_loader = get_loader(dataset=train_dataset, batch_size=BATCH_SIZE)
# Out:
# Using downloaded and verified file: C:\Users\matia\.medmnist\dermamnist_128.npz

# %%
x, y = train_dataset[0]

print(np.array(x).shape, y.shape)
# Out:
# (128, 128, 3) (1,)

# %%
for x, y in train_loader:
    print(x.shape, y.shape)
    break
# Out:
# Size 7007
# (128, 128, 128, 3) (128, 1)

# %%
train_dataset.montage(length=5)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %% [markdown]
# # We then check a 3D dataset with size 28x28x28

# %%
data_flag = 'organmnist3d'
download = True

info = INFO[data_flag]
DataClass = getattr(dataset_without_pytorch, info['python_class'])

# load the data
train_dataset = DataClass(split='train',  download=download)

# encapsulate data into dataloader form
train_loader = get_loader(dataset=train_dataset, batch_size=BATCH_SIZE)
# Out:
# Using downloaded and verified file: /home/sr/.medmnist/organmnist3d.npz

# %%
x, y = train_dataset[0]

print(x.shape, y.shape)
# Out:
# (1, 28, 28, 28) (1,)

# %%
for x, y in train_loader:
    print(x.shape, y.shape)
    break
# Out:
# Size 971
# (128, 1, 28, 28, 28) (128, 1)

# %%
frames = train_dataset.montage(length=1, save_folder="tmp/")
frames[10]
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %%
frames = train_dataset.montage(length=20, save_folder="tmp_without_pytorch/")

frames[10]
# Out:
# <PIL.Image.Image image mode=L size=560x560>

# %% [markdown]
# ## Go and check the generated [gif](tmp_without_pytorch/organmnist3d_train_montage.gif) ;)

# %% [markdown]
# # We then check a 3D dataset with size 64x64x64

# %%
data_flag = 'organmnist3d'
download = True

info = INFO[data_flag]
DataClass = getattr(dataset_without_pytorch, info['python_class'])

# load the data
train_dataset = DataClass(split='train',  download=download, size=64)

# encapsulate data into dataloader form
train_loader = get_loader(dataset=train_dataset, batch_size=BATCH_SIZE)
# Out:
# Using downloaded and verified file: /home/sr/.medmnist/organmnist3d_64.npz

# %%
x, y = train_dataset[0]

print(x.shape, y.shape)
# Out:
# (1, 64, 64, 64) (1,)

# %%
for x, y in train_loader:
    print(x.shape, y.shape)
    break
# Out:
# Size 971
# (128, 1, 64, 64, 64) (128, 1)

# %%
frames = train_dataset.montage(length=8, save_folder="tmp_without_pytorch/")

frames[10]
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %% [markdown]
# ## Go and check the generated [gif](tmp_without_pytorch/organmnist3d_64_train_montage.gif) ;)

# %% [markdown]
# # Check [EXTERNAL] [`MedMNIST/experiments`](https://github.com/MedMNIST/experiments)
#
# Training and evaluation scripts to reproduce both 2D and 3D experiments in our paper, including PyTorch, auto-sklearn, AutoKeras and Google AutoML Vision together with their weights ;)
